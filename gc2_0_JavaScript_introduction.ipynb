# %% [markdown]
# ### Practice

# %%
from IPython.display import Image
Image("E:/code/frontend/img/js8.png")

# %%
from IPython.display import Image
Image("E:/code/frontend/img/js9.png")

# %%
from IPython.display import Image
Image("E:/code/frontend/img/js10.png")

# %%
from IPython.display import Image
Image("E:/code/frontend/img/js11.png")

# %%
from IPython.display import Image
Image("E:/code/frontend/img/js16.png")

# %%
from IPython.display import Image
Image("E:/code/frontend/img/js17.png")

# %%
from IPython.display import Image
Image("E:/code/frontend/img/js12.png")

# %%
from IPython.display import Image
Image("E:/code/frontend/img/js13.png")

# %%
from IPython.display import Image
Image("E:/code/frontend/img/js14.png")

# %%
from IPython.display import Image
Image("E:/code/frontend/img/js15.png")
