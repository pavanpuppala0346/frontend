# %% [markdown]
# ### previous concepts

# %% [markdown]
# #### Event Listeners and more events
# - addEventListener()
# #### Keyboard Events
# - keydown
# - keyup
# #### Event Object
# - event.type
# - event.target
# - event.key

# %% [markdown]
# #### Hyper Text Transfer Protocol(Http)

# %%
from IPython.display import Image
Image("E:/code/frontend/img/http1.png")

# %% [markdown]
# #### Internet Web Resource
# - A web resource is any data which is present in servers that can be obtained via internet
# - a resource can be
#     - HTML document
#     - CSS document
#     - JSON data or plain text
#     - Image, Video etc

# %% [markdown]
# #### How do we access the Web Resources stored in the server?
# - Uniform Resource Locator(URL) : it is a text string that specifies where a resource can be found on the internet
# - syntax: protocol://domainName/path?query-parameters

# %%
from IPython.display import Image
Image("E:/code/frontend/img/http2.png")

# %% [markdown]
# #### protocol:
# - A protocol is a standard set of rules that allow electronic devices to communicate with each other
#
# #### web communication Protocols
# - HTTP : It is used to transfer resource over the web
# - HTTPS : In Hyper text transfer protocol secure information is transferred in an encrypted format. it provides secure communication
# - web sockets

# %%
from IPython.display import Image
Image("E:/code/frontend/img/http3.png")

# %% [markdown]
# #### Domain Name:
# - it indicates which web server is being requested
# - to which server i need to communicate

# %%
from IPython.display import Image
Image("E:/code/frontend/img/http4.png")

# %% [markdown]
#  #### path
# - To identify the resources on the server

# %%
from IPython.display import Image
Image("E:/code/frontend/img/http5.png")

# %% [markdown]
# #### Query Parameters
# - add some criteria to the request for the resource

# %%
from IPython.display import Image
Image("E:/code/frontend/img/http6.png")

# %% [markdown]
# #### multiple query parameters : we can added using &

# %%
from IPython.display import Image
Image("E:/code/frontend/img/http7.png")

# %% [markdown]
# ### How do we get the resource from the server using URL?
# - HTTP Request: HTTP requests are messages sent by the client to initiate an action on the server
# - HTTP Response: HTTP responses are the messages sent by the server as a answer to the client's request

# %%
from IPython.display import Image
Image("E:/code/frontend/img/http8.png")

# %%
from IPython.display import Image
Image("E:/code/frontend/img/http9.png")

# %% [markdown]
# - 200(sucess) : indicates the request has succeeded
# - 201(created) : the request has been succeeded and a new resource has been created as a result

# %%
from IPython.display import Image
Image("E:/code/frontend/img/http10.png")

# %% [markdown]
# ## Intro to Express JS

# %%
from IPython.display import Image
Image("E:/code/frontend/img/express1.png")

# %% [markdown]
# #### 1. what HTTP Server do?
# - works with HTTP requests and responses
# - Handles the different paths
# - Handles the query parameters
# - able to send content as HTML, CSS etc as a HTTP Response
# - able to works with databases
#
# #### Server side web frameworks : it will take care of all the above requirements
# - express (Node Js)
# - Django (Python)
# - Ruby on rails(Ruby)
# - Spring Boot(Java)
#
# #### 2. Express JS
# - It is a free and open-source Server-side Web Application Framework for Node JS.
# - It provides a robust set of features to build web and mobile applications quickly and easily.
#     - Installation Command: npm install express --save
#
# #### 3. Network call using Express JS
# - Creating Express server instance
#     - const express = require("express");
#     - const app = express();
# - Assigning a port number
#     - app.listen(3000);
# - The app starts a server and listens on port 3000 for connections.

# %%
from IPython.display import Image
Image("E:/code/frontend/img/express2.png")

# %% [markdown]
# #### 3.1 Handling HTTP Request
# - Syntax: app.METHOD(PATH, HANDLER)
# - METHOD is an HTTP request method, in lowercase like get, post, put, and delete.
# - PATH is a path on the server.
# - HANDLER is the function executed when the PATH is matched with the requested path.
# - request : express wills send the HTTP request information to the handler
# - response : to hadle the response of HTTP Request
#
# #### 3.1.1 GET Request

# %%
from IPython.display import Image
Image("E:/code/frontend/img/express3.png")

# %% [markdown]
# #### 4. Testing Network Calls
# - We can test the Network calls in two ways.
# - open Browser Network Tab. --> localhost:3000/

# %%
from IPython.display import Image
Image("E:/code/frontend/img/express4.png")

# %% [markdown]
# #### display the request object and response object

# %%
from IPython.display import Image
Image("E:/code/frontend/img/express5.png")

# %% [markdown]
# #### Another way to test the network calls

# %%
from IPython.display import Image
Image("E:/code/frontend/img/express6.png")

# %% [markdown]
# #### 5. Network Call to get a Today’s Date

# %%
from IPython.display import Image
Image("E:/code/frontend/img/express7.png")

# %% [markdown]
# #### 6. Network Call to get HTML content as an HTTP Response
# ##### 6.1 Sending file as an HTTP Response
# - Syntax: response.sendFile(PATH, {root: __dirname });
# - PATH is a path to the file which we want to send.
# - __dirname is a variable in Common JS Modules that returns the path of the folder where the current JavaScript file is present.

# %%
from IPython.display import Image
Image("E:/code/frontend/img/express8.png")

# %% [markdown]
# ## Intro to Express JS part 2

# %% [markdown]
# #### 1. Application Programming Interface (API)
# - communication between two different applications
# - An API is a software intermediary that allows two applications to talk to each other.
# - For example, OLA, and UBER use Google Maps API to provide their services.
# - All the Network calls that we added are also the APIs.
#
# #### 2. Database
# - Express apps can use any database supported by Node JS.
# - There are many popular options, including SQLite, PostgreSQL, MySQL, Redis, and MongoDB.
#
# #### 3. SQLite
# - The SQLite provides a command-line tool sqlite3.
# - It allows the user to enter and execute SQL statements against an SQLite database.
#
# ##### 3.1 SQLite CLI
# ##### 3.1.1 Listing Existing Tables
# - The .tables command is used to get the list of tables available in the SQLite database.
# ##### 3.1.2 Selecting Table Data
# - Syntax: SELECT * from <table>

# %% [markdown]
# #### 4. SQLite Methods
# ##### 4.1 Open
# - The SQLite open() method is used to connect the database server and provides a connection object to operate on the database.
# - Syntax:open({filename: DATABASE_PATH,driver: SQLITE_DATABASE_DRIVER,});
# - It returns a promise object. On resolving the promise object, we will get the database connection object.
#
# ##### 4.2 Executing SQL Queries
# - SQLite package provides multiple methods to execute SQL queries on a database.
# - Some of them are:
#     - all()
#     - get()
#     - run()
#     - exec(), etc.
#
# ##### 4.2.1 all()
# - db.all(SQL_QUERY);
# - The all() method is used to get multiple rows of data.

# %% [markdown]
# #### 5. SQL Third-party packages
# - We can use sqlite and sqlite3 node packages to connect SQLite Database from Node JS.
# - Installation Commands
#     - npm install sqlite --save
#     - npm install sqlite3 --save

# %% [markdown]
# #### 6. Connecting SQLite Database from Node JS to get the books from Goodreads Website
# - Install the SQL third-party packages sqlite and sqlite3.
# - Initialize the SQLite Database

# %% [markdown]
# ##### 6.1 SQLite Database Initialization

# %%
from IPython.display import Image
Image("E:/code/frontend/img/express9.png")

# %% [markdown]
# #### 6.2 Goodreads Get Books API

# %%
from IPython.display import Image
Image("E:/code/frontend/img/express10.png")

# %% [markdown]
# ## Intro to Express JS part 3

# %%
from IPython.display import Image
Image("E:/code/frontend/img/express11.png")

# %% [markdown]
# session initial setup: The npm install command installs all the dependancies(packages) listed in the package.json file

# %% [markdown]
# #### 1. SQLite Methods
# - The SQLite package provides multiple methods to execute SQL queries on a database.
# - Some of them are:
#     - all()
#     - get()
#     - run()
#     - exec(), etc.
#
# ##### 1.1 get() : The get() method is used to get a single row from the table.
# - Syntax: db.get(SQL_QUERY);
#
# ##### 1.2 run() : The run() method is used to create or update table data.
# - Syntax: db.run(SQL_QUERY);

# %% [markdown]
# #### 2. Node JS Third-party packages
# ##### 2.1 Nodemon : The Nodemon is a tool that restarts the server automatically whenever we make changes in the file.
# - Installation Command: npm install -g nodemon
# - The-g indicates that the nodemon will be installed globally in the environment.
# - While executing the file, replace the node with the nodemon. For example, nodemon index.js.

# %% [markdown]
# #### 3. GoodReads APIs
#     - Get Book
#     - Add Book
#     - Update Book
#     - Delete Book
#     - Get Author Books
# ##### 3.1 Get Book : We can use /books/:bookId/ as a path to identify a single book resource, where bookId is a path parameter.
# - For example, In http://localhost:3000/books/1/, the bookId is 1.

# %%
from IPython.display import Image
Image("E:/code/frontend/img/express12.png")

# %% [markdown]
# #### Note: Any string can be used as a path parameter.

# %% [markdown]
# #### 3.2 Add Book
# - To add a book to the Database, you need to send a request body in JSON format.
# - The express.json() is used to recognize the incoming request object as JSON Object and parses it.
# - The request.body is used to get the HTTP Request body.

# %%
from IPython.display import Image
Image("E:/code/frontend/img/express13.png")

# %% [markdown]
# The dbResponse.lastID provides the primary key of the new row inserted.

# %% [markdown]
# #### 3.3 Update Book
# - We can use /books/:bookId/ as a path to identify a single book resource, where :bookId is the path parameter.
# - For example, http://localhost:3000/books/1/.

# %%
from IPython.display import Image
Image("E:/code/frontend/img/express14.png")

# %% [markdown]
# - The request.params provides the parameters passed through the request.
# #### Note: The strings sent through the APIs must be wrapped in quotes.

# %% [markdown]
# #### 3.4 Delete Book

# %%
from IPython.display import Image
Image("E:/code/frontend/img/express15.png")

# %% [markdown]
# #### 3.5 Get Author Books

# %%
from IPython.display import Image
Image("E:/code/frontend/img/express16.png")

# %% [markdown]
# ## Rest API

# %% [markdown]
# #### 1. Get Books API
# - Let's see how to add Filters to Get Books API
#
# ##### 1.1 Filtering Books
# - Get a specific number of books
# - Get books based on search query text
# - Get books in the sorted order
# ##### 1.1.1 Get a specific number of books
# - To get specific number of books in certain range we use limit and offset.
# - Offset is used to specify the position from where rows are to be selected.
# - Limit is used to specify the number of rows. and many more...
# - Query parameters starts with ? (question mark) followed by key value pairs separated by & (ampersand)
#
# Example :
# - http://localhost:3000/books/?limit=2
# - http://localhost:3000/books/?offset=2&limit=3
# - http://localhost:3000/authors/20/books/?offset=2

# %% [markdown]
# #### Note:
# - The query parameters are used to sort/filter resources.
# - The path parameters are used to identify a specific resource(s)

# %% [markdown]
# ###### Accessing Query Parameters
# - Query parameters are stored inside a request.query object in the form of key value pairs

# %% [markdown]
# ##### request object

# %%
from IPython.display import Image
Image("E:/code/frontend/img/rest1.png")

# %% [markdown]
# ##### 1.1.2 Get books based on search query text
# - We provide query text to search_q key(search_q = potter)
# ##### 1.1.3 Get books in the sorted order
# - We provide sorted order to order key
#     - Ascending: ASC
#     - DESCENDING: DESC
#         - order = ASC
#         - order = DESC

# %%
from IPython.display import Image
Image("E:/code/frontend/img/rest2.png")

# %% [markdown]
# #### Filtering GET Books API

# %%
from IPython.display import Image
Image("E:/code/frontend/img/react3.png")

# %%
from IPython.display import Image
Image("E:/code/frontend/img/express17.png")

# %% [markdown]
# #### NOTE
# - We can skip or add slash while appending query parameters to the URL
# - http://localhost:3000/books/?offset=2&limit=3 is same as http://localhost:3000/books?offset=2&limit=3

# %% [markdown]
# #### 2. REST APIs
# - REST: Representational State Transfer
# - REST is a set of principles that define how Web standards, such as HTTP and URLs, are supposed to be used.
#
# ##### 2.1 Why Rest Principles?
# - Using Rest Principles improves application in various aspects like scalability, reliability etc
#
# ##### 2.2 REST API Principles
# - Providing unique ID to each resource
# - Using standard methods like GET, POST, PUT, and DELETE
# - Accept and Respond with JSON and many more...
