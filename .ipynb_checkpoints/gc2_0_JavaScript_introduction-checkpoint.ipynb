# %% [markdown]
# ### Practice

# %%
from IPython.display import Image
Image("E:/code/frontend/img/js8.png")

# %%
from IPython.display import Image
Image("E:/code/frontend/img/js9.png")

# %%
from IPython.display import Image
Image("E:/code/frontend/img/js10.png")

# %%
from IPython.display import Image
Image("E:/code/frontend/img/js11.png")

# %%
from IPython.display import Image
Image("E:/code/frontend/img/js16.png")

# %%
from IPython.display import Image
Image("E:/code/frontend/img/js17.png")

# %%
from IPython.display import Image
Image("E:/code/frontend/img/js12.png")

# %%
from IPython.display import Image
Image("E:/code/frontend/img/js28.png")

# %%
from IPython.display import Image
Image("E:/code/frontend/img/js29.png")

# %%
from IPython.display import Image
Image("E:/code/frontend/img/js13.png")

# %%
from IPython.display import Image
Image("E:/code/frontend/img/js29.png")

# %%
from IPython.display import Image
Image("E:/code/frontend/img/js14.png")

# %%
from IPython.display import Image
Image("E:/code/frontend/img/js15.png")

# %% [markdown]
# #### Topic2

# %%
from IPython.display import Image
Image("E:/code/frontend/img/js31.png")

# %%
from IPython.display import Image
Image("E:/code/frontend/img/js33.png")

# %%
from IPython.display import Image
Image("E:/code/frontend/img/js32.png")

# %%
from IPython.display import Image
Image("E:/code/frontend/img/js34.png")

# %%
from IPython.display import Image
Image("E:/code/frontend/img/js35.png")

# %% [markdown]
# #### Topic3

# %%
from IPython.display import Image
Image("E:/code/frontend/img/js36.png")

# %%
from IPython.display import Image
Image("E:/code/frontend/img/js37.png")
